# %%
import pandas as pd

# %%
df = pd.read_csv(r'/content/8. Netflix Dataset.csv')
df
# Out:
#      Show_Id  ...                                        Description
# 0         s1  ...  In a future where the elite inhabit an island ...
# 1         s2  ...  After a devastating earthquake hits Mexico Cit...
# 2         s3  ...  When an army recruit is found dead, his fellow...
# 3         s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4         s5  ...  A brilliant group of students become card-coun...
# ...      ...  ...                                                ...
# 7784   s7783  ...  When Lebanon's Civil War deprives Zozo of his ...
# 7785   s7784  ...  A scrappy but poor boy worms his way into a ty...
# 7786   s7785  ...  In this documentary, South African rapper Nast...
# 7787   s7786  ...  Dessert wizard Adriano Zumbo looks for the nex...
# 7788   s7787  ...  This documentary delves into the mystique behi...
#
# [7789 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.head()
# Out:
#   Show_Id  ...                                        Description
# 0      s1  ...  In a future where the elite inhabit an island ...
# 1      s2  ...  After a devastating earthquake hits Mexico Cit...
# 2      s3  ...  When an army recruit is found dead, his fellow...
# 3      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4      s5  ...  A brilliant group of students become card-coun...
#
# [5 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# ***check duplicates and remove***

# %%
df[df.duplicated()]
# Out:
#      Show_Id  ...                                        Description
# 6300    s684  ...  When two would-be robbers accidentally kill a ...
# 6622   s6621  ...  A disillusioned security guard transforms into...
#
# [2 rows x 11 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# ***is there any null values prsent ...show with heat map***
#
# ---

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.isnull())

# %% [markdown]
# ***for house of cards what is show id and who is the director of show***

# %%
df[df['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id  ...                                        Description
# 2832   s2833  ...  A ruthless politician will stop at nothing to ...
#
# [1 rows x 11 columns]

# %% [markdown]
# ***in which year highest no of show are released and show with it bar graph***

# %%
df['year']=pd.to_datetime(df['Release_Date'])

# %%
df.head(1)
# Out:
#   Show_Id  ...       year
# 0      s1  ... 2020-08-14
#
# [1 rows x 12 columns]

# %%
df['year'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: year, dtype: int64

# %%
df['year'].dt.year.value_counts().plot(kind='bar')

# %% [markdown]
# ***how many movies and tv shows are in the dataset show with bar graph***

# %%
df.head(1)
# Out:
#   Show_Id  ...       year
# 0      s1  ... 2020-08-14
#
# [1 rows x 12 columns]

# %%
df.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(df['Category'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ***show all the movies that were released in the year 2000***

# %%
df['year_only']=df['year'].dt.year

# %%
df.head(1)
# Out:
#   Show_Id Category  ...       year year_only
# 0      s1  TV Show  ... 2020-08-14    2020.0
#
# [1 rows x 13 columns]

# %%
df[(df['Category']== 'Movie') & (df['year_only']== '2000')]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, year, year_only]
# Index: []

# %% [markdown]
# ***show top 10 directors who gave highest no of tv show and movies on the netflix***

# %%
df['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Martin Scorsese           12
# Jay Chapman               12
# Steven Spielberg          10
# David Dhawan               9
# Quentin Tarantino          8
# Name: Director, dtype: int64

# %% [markdown]
# ***in how many movies tom cruise was cast***

# %%
df[(df['Cast']== 'Tom Cruise')]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, year, year_only]
# Index: []

# %%
df[df['Cast'].str.contains('Tom cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-1b9742dc4ef9> in <module>()
# ----> 1 df[df['Cast'].str.contains('Tom cruise')]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2894
#    2895         # Do we have a (boolean) 1d indexer?
# -> 2896         if com.is_bool_indexer(key):
#    2897             return self._getitem_bool_array(key)
#    2898
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     132                 na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133                 if isna(key).any():
# --> 134                     raise ValueError(na_msg)
#     135                 return False
#     136             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %% [markdown]
# ***creating new dataframe to drop na ***

# %%
df_new = df.dropna()
df_new.head(1)
# Out:
#   Show_Id Category  ...       year year_only
# 1      s2    Movie  ... 2016-12-23    2016.0
#
# [1 rows x 13 columns]

# %%
df_new[df_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category  ...       year year_only
# 3860   s3861    Movie  ... 2020-01-01    2020.0
# 5071   s5071    Movie  ... 2019-07-01    2019.0
#
# [2 rows x 13 columns]

# %% [markdown]
# ***what are the different ratings defined by netflix***

# %%
df['Rating'].nunique()
# Out:
# 14

# %%
df['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ***how many movies got the rating TV-14 in canada***

# %%
df[(df['Category']=='Movie') & (df['Rating']=='TV-14')]
# Out:
#      Show_Id Category  ...       year year_only
# 8         s9    Movie  ... 2019-04-01    2019.0
# 15       s16    Movie  ... 2019-09-01    2019.0
# 18       s19    Movie  ... 2019-03-29    2019.0
# 20       s21    Movie  ... 2018-09-01    2018.0
# 21       s22    Movie  ... 2018-09-15    2018.0
# ...      ...      ...  ...        ...       ...
# 7765   s7764    Movie  ... 2018-02-15    2018.0
# 7766   s7765    Movie  ... 2019-05-21    2019.0
# 7770   s7769    Movie  ... 2018-10-01    2018.0
# 7771   s7770    Movie  ... 2019-12-15    2019.0
# 7785   s7784    Movie  ... 2019-03-02    2019.0
#
# [1272 rows x 13 columns]

# %%
df[(df['Category']=='Movie') & (df['Rating']=='TV-14')].shape
# Out:
# (1272, 13)

# %%
df[(df['Category']=='Movie') & (df['Rating']=='TV-14')&(df['Country']=='Canada')].shape
# Out:
# (11, 13)

# %% [markdown]
# ***how many shows got the 'R' rating after year 2018***

# %%
df[(df['Category']=='TV Show') & (df['Rating']=='R')& (df['year_only']>2018)]
# Out:
#      Show_Id Category  ...       year year_only
# 6437   s6436  TV Show  ... 2019-04-25    2019.0
#
# [1 rows x 13 columns]

# %% [markdown]
# ***what is the maximum duration of show/movie on netflix***

# %%
df.head(1)
# Out:
#   Show_Id Category  ...       year year_only
# 0      s1  TV Show  ... 2020-08-14    2020.0
#
# [1 rows x 13 columns]

# %%
df['Duration'].unique
# Out:
# <bound method Series.unique of 0       4 Seasons
# 1          93 min
# 2          78 min
# 3          80 min
# 4         123 min
#           ...
# 7784       99 min
# 7785      111 min
# 7786       44 min
# 7787     1 Season
# 7788       90 min
# Name: Duration, Length: 7787, dtype: object>

# %%
df['Duration'].dtypes
# Out:
# dtype('O')

# %%
df[['Minute','unit']]=df['Duration'].str.split(' ',expand= True)
df.head(2)
# Out:
#   Show_Id Category  Title  ... year_only Minute     unit
# 0      s1  TV Show     3%  ...    2020.0      4  Seasons
# 1      s2    Movie  07:19  ...    2016.0     93      min
#
# [2 rows x 15 columns]

# %%
df['Minute'].max()
# Out:
# '99'

# %% [markdown]
# ***which country has highest no og TV show?***

# %%
df_tvshow = df[df['Category']=='TV Show']
df_tvshow.head(2)
# Out:
#   Show_Id Category Title     Director  ...       year year_only Minute     unit
# 0      s1  TV Show    3%          NaN  ... 2020-08-14    2020.0      4  Seasons
# 5      s6  TV Show    46  Serdar Akar  ... 2017-07-01    2017.0      1   Season
#
# [2 rows x 15 columns]

# %%
df_tvshow['Country'].value_counts()
# Out:
# United States                                                 705
# United Kingdom                                                204
# Japan                                                         157
# South Korea                                                   147
# India                                                          71
#                                                              ...
# United States, United Kingdom, Australia                        1
# Italy, United States                                            1
# Germany, United States                                          1
# United States, Brazil, South Korea, Mexico, Japan, Germany      1
# Australia, Canada                                               1
# Name: Country, Length: 183, dtype: int64

# %% [markdown]
# ***sort the data set by year***

# %%
df.sort_values(by='year_only',ascending=False)
# Out:
#      Show_Id Category                         Title  ... year_only Minute     unit
# 5564   s5564    Movie               Sherlock Holmes  ...    2021.0    128      min
# 5919   s5919    Movie                     Surf's Up  ...    2021.0     86      min
# 980     s981  TV Show                  Bling Empire  ...    2021.0      1   Season
# 5955   s5955    Movie              Taare Zameen Par  ...    2021.0    162      min
# 366     s367    Movie                     Al acecho  ...    2021.0     81      min
# ...      ...      ...                           ...  ...       ...    ...      ...
# 3374   s3375  TV Show                      Kikoriki  ...       NaN      2  Seasons
# 3492   s3493  TV Show           La Familia P. Luche  ...       NaN      3  Seasons
# 3946   s3947  TV Show                         Maron  ...       NaN      4  Seasons
# 5138   s5138  TV Show                  Red vs. Blue  ...       NaN     13  Seasons
# ...

# %% [markdown]
# ***find all instances where category is movie and type is drama or find all instances where category is TV show and type is kids***

# %%
df[(df['Category']=='Movie') & (df['Type']=='Dramas')]
# Out:
#      Show_Id Category                       Title  ... year_only Minute unit
# 4         s5    Movie                          21  ...    2020.0    123  min
# 7         s8    Movie                         187  ...    2019.0    119  min
# 170     s171    Movie                A Family Man  ...    2019.0    110  min
# 232     s233    Movie  A Stoning in Fulham County  ...    2011.0     95  min
# 295     s296    Movie          Across Grace Alley  ...    2016.0     24  min
# ...      ...      ...                         ...  ...       ...    ...  ...
# 7417   s7416    Movie                      Victor  ...    2017.0    110  min
# 7422   s7421    Movie                     Villain  ...    2020.0     97  min
# 7449   s7448    Movie                         VS.  ...    2019.0     99  min
# 7465   s7464    Movie                   Wakefield  ...    2019.0    109  min
# 7480   s7479    Movie                   War Horse  ...    2019.0    147  min
#
# [117 rows x 15 columns]

# %%
df[(df['Category']=='TV Show') & (df['Type']=="Kids' TV")]
# Out:
#      Show_Id Category              Title  ... year_only Minute     unit
# 111     s112  TV Show            44 Cats  ...    2020.0      2  Seasons
# 276     s277  TV Show       Abby Hatcher  ...    2020.0      1   Season
# 434     s435  TV Show        Alphablocks  ...    2020.0      5  Seasons
# 598     s599  TV Show  Ask the StoryBots  ...    2019.0      3  Seasons
# 706     s707  TV Show         Bal Ganesh  ...    2020.0      1   Season
# ...      ...      ...                ...  ...       ...    ...      ...
# 7668   s7667  TV Show      World of Winx  ...    2017.0      2  Seasons
# 7717   s7716  TV Show               Yoko  ...    2018.0      1   Season
# 7719   s7718  TV Show                YOM  ...    2018.0      1   Season
# 7758   s7757  TV Show                 Z4  ...    2019.0      2  Seasons
# 7761   s7760  TV Show          Zak Storm  ...    2018.0      3  Seasons
#
# [205 rows x 15 columns]

# %%
df[(df['Category']=='Movie') & (df['Type']=='Dramas') | (df['Category']=='TV Show') & (df['Type']=="Kids' TV")]
# Out:
#      Show_Id Category                       Title  ... year_only Minute     unit
# 4         s5    Movie                          21  ...    2020.0    123      min
# 7         s8    Movie                         187  ...    2019.0    119      min
# 111     s112  TV Show                     44 Cats  ...    2020.0      2  Seasons
# 170     s171    Movie                A Family Man  ...    2019.0    110      min
# 232     s233    Movie  A Stoning in Fulham County  ...    2011.0     95      min
# ...      ...      ...                         ...  ...       ...    ...      ...
# 7668   s7667  TV Show               World of Winx  ...    2017.0      2  Seasons
# 7717   s7716  TV Show                        Yoko  ...    2018.0      1   Season
# 7719   s7718  TV Show                         YOM  ...    2018.0      1   Season
# 7758   s7757  TV Show                          Z4  ...    2019.0      2  Seasons
# 7761   s7760  TV Show                   Zak Storm  ...    2018.0      3  Seasons
#
# ...
